# %% [markdown]
# # Data Mining - StarCraft Player Prediction
#
# The goal of the project was it to predict which player is playing a certain game based on the moves he or she made.

# %%
# imports
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.utils.class_weight import compute_class_weight
from itertools import groupby, combinations
import numpy as np
import joblib
import warnings
# Suppress all warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Pre-processing Training Data

# %% [markdown]
# To train a model we were given data where each row represented a gameplay. A row included information about the race, the player who was playing and the moves he or she made during the game.

# %%
# Load the training dataset
train_data = pd.read_csv('train_data.csv', delimiter=';')

# Drop unnecessary columns
train_data = train_data.drop(['PlayerURL', 'PlayerName'], axis=1)

train_data.head()
# Out:
#    PlayerID    Race Move 1    Move 2    Move 3    Move 4    Move 5    Move 6  \
# 0   1021189  Terran      s  hotkey11  hotkey21  hotkey31  hotkey41  hotkey51
# 1   1021189  Terran      s         s  hotkey11  hotkey21  hotkey31  hotkey41
# 2   1021189  Terran      s  hotkey11  hotkey21  hotkey31  hotkey41  hotkey51
# 3   1021189  Terran      s  hotkey11  hotkey21  hotkey31  hotkey41  hotkey51
# 4   1021189  Terran      s  hotkey11  hotkey21  hotkey31  hotkey41  hotkey51
#
#      Move 7    Move 8  ... Move 2554 Move 2555 Move 2556 Move 2557 Move 2558  \
# 0  hotkey61         s  ...       NaN       NaN       NaN       NaN       NaN
# 1  hotkey51  hotkey61  ...       NaN       NaN       NaN       NaN       NaN
# 2  hotkey61  hotkey71  ...       NaN       NaN       NaN       NaN       NaN
# 3  hotkey61        t5  ...       NaN       NaN       NaN       NaN       NaN
# 4  hotkey71  hotkey61  ...       NaN       NaN       NaN       NaN       NaN
#
#   Move 2559 Move 2560 Move 2561 Move 2562 Move 2563
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 2565 columns]

# %% [markdown]
# Before starting with the classification algorithms we had to find a way to process our data and make it comparable. We wanted to reduce dimensions without losing information. In order to do so, we started counting how often a player would use a certain move. We did this over the course of a whole game and also over the course of certain time periods.

# %%
def count_moves(row, counts, index):
    total_moves = 0
    for i in range(1, 2564):
        move = row["Move "+ str(i)]
        # count the number of s's
        if move == 's':
            counts[10][index] += 1
        # count the number of Base's
        elif move == 'Base':
            counts[11][index] += 1
        # count the number of SingleMineral's
        elif move == 'SingleMineral':
            counts[12][index] += 1
        # count the hotkeys
        elif isinstance(move, str):
            for j in range(10):
                if move.startswith(f"hotkey{j}"):
                    counts[j][index] += 1

        total_moves += 1  
    # Save the total moves count
    counts[13][index] = total_moves


def count_move_per_time(row, counts, row_index, time_interval, ti_index):
    base_index = ti_index * 14
    total_moves = 0

    for i in range(1, 2564):
        move = row["Move " + str(i)]

        # Count actions for the given time interval
        if move == 's':
            counts[base_index + 10][row_index] += 1
        elif move == 'Base':
            counts[base_index + 11][row_index] += 1
        elif move == 'SingleMineral':
            counts[base_index + 12][row_index] += 1
        elif isinstance(move, str):
            for j in range(10):
                if move.startswith(f"hotkey{j}"):
                    counts[base_index + j][row_index] += 1

        total_moves += 1

        # Counting actions after the specified time interval
        if move == f't{time_interval}':
            break

    counts[base_index + 13][row_index] = total_moves

# Create new table that only contains the first column (PlayerId) of train_data
# Keep only the first column but all rows
train_data_new = train_data.iloc[:, :1]

# Specify the target time intervals
# time_intervals = [20, 60, 100, 200]
time_intervals = [5, 20, 60, 100, 200, 270, 340, 550]

# Calculate how many columns we need
calc_column = len(time_intervals)* 14 + 14

# New lists of counts
counts = [[0] * 3052 for _ in range(calc_column)]

# Go through the rows using the functions to count the actions
for row_index, row in train_data.iterrows():
    count_moves(row, counts, row_index)

    for ti_index, time_interval in enumerate(time_intervals):
        count_move_per_time(row, counts, row_index, time_interval, ti_index+1)

train_data_new["sCount"] = counts[10]
train_data_new["BaseCount"] = counts[11]
train_data_new["singleMineralCount"] = counts[12]

for i in range(10):
    train_data_new[f'hk{i}Count'] = counts[i]

for ti_index, time_interval in enumerate(time_intervals):
    base_index = (ti_index + 1) * 14
    
    train_data_new[f's_t{time_interval}Count'] = counts[base_index + 10]
    train_data_new[f'base_t{time_interval}Count'] =  counts[base_index + 11]
    train_data_new[f'singleMineral_t{time_interval}Count'] = counts[base_index + 12]
    
    for j in range(10):
        column_name = f'hk{j}_t{time_interval}Count'
        train_data_new[column_name] = counts[base_index + j]
    
train_data_new.head()
# Out:
#    PlayerID  sCount  BaseCount  singleMineralCount  hk0Count  hk1Count  \
# 0   1021189    1245          0                   2         0       405
# 1   1021189     458          0                   0         0       382
# 2   1021189     879          0                   8         0       334
# 3   1021189     956          0                   9         0       427
# 4   1021189     927          0                   3         0       396
#
#    hk2Count  hk3Count  hk4Count  hk5Count  ...  hk0_t550Count  hk1_t550Count  \
# 0       275        83        77        20  ...              0            281
# 1       159       141        44         5  ...              0            360
# 2       222        48        79        16  ...              0            184
# 3       309        86       114        55  ...              0            255
# 4       198        58       107        28  ...              0            240
#
#    hk2_t550Count  hk3_t550Count  hk4_t550Count  hk5_t550Count  hk6_t550Count  \
# 0            115             66             20              2              1
# 1            143            141             40              2              1
# 2            108             35             32              1              1
# 3            161             61             79              1              1
# 4            107             33             21              2              1
#
#    hk7_t550Count  hk8_t550Count  hk9_t550Count
# 0              0              0              0
# 1              0              0              0
# 2              1              0              0
# 3              0              0              0
# 4              1              0              0
#
# [5 rows x 118 columns]

# %% [markdown]
# We then realised this was not very meaningful. How often a player presses a certain key, does not make him or her recognizable. So we decided to focus on frequency of moves. Meaning how frequent a player was using certain moves. Overall and again also over the course of certain time periods. To standardize the data we also created three new columns that mapped the name of the race (which was of type string before) to a zero or a one. Depending on whether this particular race was being played or not.
# Of course, preprocessing also included deleting unnecessary columns like Player URL and Player Name.

# %%
def count_moves(row, counts, index):
    total_moves = 0
    for i in range(1, 2564):
        move = row["Move "+ str(i)]
        # count the number of s's
        if move == 's':
            counts[10][index] += 1
        # count the number of Base's
        elif move == 'Base':
            counts[11][index] += 1
        # count the number of SingleMineral's
        elif move == 'SingleMineral':
            counts[12][index] += 1
        # count the hotkeys
        elif isinstance(move, str):
            for j in range(10):
                if move.startswith(f"hotkey{j}"):
                    counts[j][index] += 1

        total_moves += 1  
    # Save the total moves count
    counts[13][index] = total_moves


def count_move_per_time(row, counts, row_index, time_interval, ti_index):
    base_index = ti_index * 14
    total_moves = 0

    for i in range(1, 2564):
        move = row["Move " + str(i)]

        # Count actions for the given time interval
        if move == 's':
            counts[base_index + 10][row_index] += 1
        elif move == 'Base':
            counts[base_index + 11][row_index] += 1
        elif move == 'SingleMineral':
            counts[base_index + 12][row_index] += 1
        elif isinstance(move, str):
            for j in range(10):
                if move.startswith(f"hotkey{j}"):
                    counts[base_index + j][row_index] += 1

        total_moves += 1

        # Counting actions after the specified time interval
        if move == f't{time_interval}':
            break

    counts[base_index + 13][row_index] = total_moves


def mapRaces(races, row_index):
    race = train_data['Race'][row_index]

    if race == "Protoss":
        races[0][row_index] = 1
    elif race == "Terran":
        races[1][row_index] = 1
    elif race == "Zerg":
        races[2][row_index] = 1
        
# Create new table that only contains the first column (PlayerId) of train_data
# Keep only the first column but all rows
train_data_new = train_data.iloc[:, :1]


# Specify the target time intervals
#time_intervals = [20, 60, 100, 200]
time_intervals = [5, 20, 60, 100, 200, 270, 340, 550]

calc_column = len(time_intervals)* 14 + 14

# New lists of counts
counts = [[0] * 3052 for _ in range(calc_column)]
# New lists of races
races = [[0] * 3052 for _ in range(3)]


# Go through the rows using the functions to count the actions, map the races
for row_index, row in train_data.iterrows():
    count_moves(row, counts, row_index)
    mapRaces(races, row_index)

    for ti_index, time_interval in enumerate(time_intervals):
        count_move_per_time(row, counts, row_index, time_interval, ti_index+1)
        

for i in range(calc_column):
    locals()[f'count_{i}'] = counts[i]

for i in range(10):
    train_data_new[f'hk{i}Frequency'] = [count / counts[13][index] if counts[13][index] != 0 else 0 for index, count in enumerate(counts[i])]

train_data_new['sFrequency'] = [count / counts[13][index] if counts[13][index] != 0 else 0 for index, count in enumerate(counts[10])]
train_data_new['baseFrequency'] = [count / counts[13][index] if counts[13][index] != 0 else 0 for index, count in enumerate(counts[11])]
train_data_new['singleMineralFrequency'] = [count / counts[13][index] if counts[13][index] != 0 else 0 for index, count in enumerate(counts[12])]

# Adding new columns for the count of moves per interval
for ti_index, time_interval in enumerate(time_intervals):
    base_index = (ti_index + 1) * 14
    for j in range(10):
        column_name = f'hk{j}_t{time_interval}_Frequency'
        train_data_new[column_name] = [count / counts[base_index + 13][index] if counts[base_index + 13][index] != 0 else 0 for index, count in enumerate(counts[base_index + j])]

    train_data_new[f's_t{time_interval}_Frequency'] = [count / counts[base_index + 13][index] if counts[base_index + 13][index] != 0 else 0 for index, count in enumerate(counts[base_index + 10])]
    train_data_new[f'base_t{time_interval}_Frequency'] = [count / counts[base_index + 13][index] if counts[base_index + 13][index] != 0 else 0 for index, count in enumerate(counts[base_index + 11])]
    train_data_new[f'singleMineral_t{time_interval}_Frequency'] = [count / counts[base_index + 13][index] if counts[base_index + 13][index] != 0 else 0 for index, count in enumerate(counts[base_index + 12])]



# Adding new columns for the races
train_data_new['race_Protoss'] = races[0]
train_data_new['race_Terran'] = races[1]
train_data_new['race_Zerg'] = races[2]

# Saving them in a csv file
train_data_new.to_csv('actiontype_count.csv', index=False)

train_data_new.head()
# Out:
#    PlayerID  hk0Frequency  hk1Frequency  hk2Frequency  hk3Frequency  \
# 0   1021189           0.0      0.158018      0.107296      0.032384
# 1   1021189           0.0      0.149044      0.062037      0.055014
# 2   1021189           0.0      0.130316      0.086617      0.018728
# 3   1021189           0.0      0.166602      0.120562      0.033554
# 4   1021189           0.0      0.154506      0.077253      0.022630
#
#    hk4Frequency  hk5Frequency  hk6Frequency  hk7Frequency  hk8Frequency  ...  \
# 0      0.030043      0.007803      0.000390       0.00000           0.0  ...
# 1      0.017167      0.001951      0.000390       0.00000           0.0  ...
# 2      0.030823      0.006243      0.000390       0.00039           0.0  ...
# 3      0.044479      0.021459      0.001171       0.00000           0.0  ...
# 4      0.041748      0.010925      0.000390       0.00039           0.0  ...
#
#    hk6_t550_Frequency  hk7_t550_Frequency  hk8_t550_Frequency  \
# 0            0.000994            0.000000                 0.0
# 1            0.000853            0.000000                 0.0
# 2            0.001289            0.001289                 0.0
# 3            0.000971            0.000000                 0.0
# 4            0.001104            0.001104                 0.0
#
#    hk9_t550_Frequency  s_t550_Frequency  base_t550_Frequency  \
# 0                 0.0          0.407555                  0.0
# 1                 0.0          0.320546                  0.0
# 2                 0.0          0.389175                  0.0
# 3                 0.0          0.350485                  0.0
# 4                 0.0          0.429360                  0.0
#
#    singleMineral_t550_Frequency  race_Protoss  race_Terran  race_Zerg
# 0                      0.000994             0            1          0
# 1                      0.000000             0            1          0
# 2                      0.002577             0            1          0
# 3                      0.000971             0            1          0
# 4                      0.002208             0            1          0
#
# [5 rows x 121 columns]

# %% [markdown]
# By analysing our train dataset, we realised that the same player uses typically the same sequence of moves, for a certain race type, in the first 10 seconds with slight variations. So we wanted to find a unique sequence for each player that immediately identified him by the use of a specific combination of moves, for a specific type of race played.
# We started working on this idea by creating a function for the research of consecutive sequences of moves, excluding the time data,'t5' and 't10' and iterate the process for each player to find the action sequences.
# At the end we saved the found sequences to a text file.
# We proceeded by defining a function to evaluate the combination of sequences based on their uniqueness, and applied to each player to obtain ranked combinations.

# %%
# Get the indices for columns 'Move_1' to 'Move_50'
move_columns = [f'Move_{i}' for i in range(1, 68)]

data_10s = []

# Iterate through each row of the dataframe
for _, row in train_data.iterrows():
    row_actions = []

    # Iterate through each 'Move_XX' column for the current row
    for col in train_data.columns[3:70]:
        row_actions.append(row[col])

        # Check if the current action is 't10'
        if row[col] == 't10':  # Assuming 't10' is converted to 100 in your previous processing
            break  # Stop iterating if 't10' is found

    data_10s.append(row_actions)

# Convert the result to a new dataframe if needed
data_10s_df = pd.DataFrame(data_10s, columns=move_columns)

data_10s_df.insert(0, 'PlayerID', train_data['PlayerID'])
data_10s_df.insert(1, 'Race', train_data['Race'])

data_10s_df.to_csv('data_10s.csv', index=False)

# Load the data_10s.csv file
data_10s_df = pd.read_csv('data_10s.csv')

# Get the move columns
move_columns = [f'Move_{i}' for i in range(1, 68)]

# Flatten the dataframe to have a single column of moves
all_moves = data_10s_df[move_columns].values.flatten()

# Count the frequency of each move
moves_frequency = {}
for move in all_moves:
    if pd.notna(move):  # Exclude NaN values
        moves_frequency[move] = moves_frequency.get(move, 0) + 1

print("Moves Frequency:")
for move, frequency in moves_frequency.items():
    print(f"{move}: {frequency}")

# Group the data by PlayerID and reset the index
grouped_data = data_10s_df.groupby('PlayerID')[move_columns].apply(lambda x: x.reset_index(drop=True))

# Define a function to find sequences of consecutive moves
def find_sequences(group):
    sequences = []
    for _, g in groupby(enumerate(group), key=lambda x: int(x[1] == 't10')):
        consecutive_moves = list(map(lambda x: x[1], g))

        # Remove 't5' and 't10' from consecutive_moves
        consecutive_moves = [move for move in consecutive_moves if move not in ['t5', 't10']]

        sequences.append(consecutive_moves)
    return sequences

# Iterate through each player's moves and find sequences
player_sequences = {}
for player, moves in grouped_data.iterrows():
    sequences = find_sequences(moves.dropna().astype(str))
    player_sequences[player] = sequences

# Save the found sequences to a text file
output_file_path = 'sequences.txt'
with open(output_file_path, 'w') as file:
    for player, sequences in player_sequences.items():
        file.write(f"{player} : \t")
        for sequence in sequences:
            file.write(','.join(sequence) + '\n')
        file.write("\n")

print(f"Sequences saved to {output_file_path}")

# Define a function to evaluate the combination of moves
def evaluate_combination(combination):
    unique_moves = set(combination[0] + combination[1])
    uniqueness_score = sum(moves_frequency.get(move, 0) for move in unique_moves)
    return uniqueness_score

# Iterate through each player's sequences and find ranked combinations
ranked_combinations = {}
for player, sequences in player_sequences.items():
    combinations_list = list(combinations(sequences, 2))
    ranked_combinations[player] = sorted(combinations_list, key=lambda x: evaluate_combination(x), reverse=True)

# Print or save the ranked combinations
for player, combinations in ranked_combinations.items():
    print(f"Player {player} ranked combinations:")
    for i, combination in enumerate(combinations, start=1):
        print(f"Rank {i}: {combination} - Score: {evaluate_combination(combination)}")

# Save the ranked combinations to a text file
output_file_path = 'ranked_combinations.txt'
with open(output_file_path, 'w') as file:
    for player, combinations in ranked_combinations.items():
        file.write(f"Player {player} ranked combinations:\n")
        for i, combination in enumerate(combinations, start=1):
            file.write(f"Rank {i}: {combination} - Score: {evaluate_combination(combination)}\n")
        file.write("\n")

print(f"Ranked combinations saved to {output_file_path}")
# Out:
# Moves Frequency:
# hotkey11: 20
# hotkey21: 41
# hotkey31: 20
# hotkey41: 54
# hotkey51: 23
# hotkey61: 43
# s: 25854
# SingleMineral: 540
# t5: 3041
# hotkey12: 5676
# hotkey22: 4988
# t10: 3039
# hotkey30: 1529
# hotkey71: 27
# hotkey32: 3827
# hotkey20: 1957
# hotkey40: 1336
# hotkey10: 1844
# hotkey90: 643
# hotkey70: 488
# hotkey80: 488
# hotkey42: 4564
# hotkey00: 881
# hotkey50: 986
# hotkey52: 2903
# Base: 1920
# hotkey81: 19
# hotkey91: 56
# hotkey01: 81
# hotkey60: 654
# hotkey62: 1120
# hotkey92: 261
# hotkey82: 94
# hotkey02: 503
# hotkey72: 67
# Sequences saved to sequences.txt
# Player (401, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey40', 's', 'hotkey20', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42'], []) - Score: 38699
# Player (401, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey40', 's', 'hotkey20', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 's', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 's', 'hotkey42', 's', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42'], []) - Score: 38699
# Player (401, 2) ranked combinations:
# Player (401, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey40', 's', 'hotkey20', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's'], []) - Score: 38699
# Player (401, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey40', 's', 'hotkey20', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 's'], []) - Score: 38699
# Player (401, 5) ranked combinations:
# Rank 1: (['Base', 's', 's', 's', 's', 'Base', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42'], []) - Score: 40619
# Player (401, 6) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey40', 's', 'hotkey20', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42'], []) - Score: 38699
# Player (401, 7) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey40', 'hotkey20', 's', 'hotkey20', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42'], []) - Score: 38699
# Player (402, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 'Base', 's', 'hotkey10', 's', 'hotkey20', 'Base', 's', 'hotkey22', 'hotkey12', 's', 'hotkey20', 'Base', 's', 'hotkey30', 'hotkey40', 'hotkey00', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 's', 'hotkey32', 'hotkey22', 's', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12'], []) - Score: 49812
# Player (402, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 'Base', 's', 'hotkey10', 's', 'hotkey20', 'Base', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 's', 'Base', 's', 'hotkey30', 'hotkey40', 'hotkey00', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32'], []) - Score: 49812
# Player (402, 2) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 'Base', 's', 'hotkey10', 's', 'Base', 's', 'hotkey30', 'hotkey40', 'hotkey00', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 's', 'hotkey32', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 's', 'hotkey20'], []) - Score: 49812
# Player (402, 3) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 'Base', 's', 'hotkey30', 'hotkey40', 'hotkey00', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 's', 'hotkey12', 'hotkey22', 'hotkey32', 's', 'hotkey20', 'Base', 's'], []) - Score: 49812
# Player (402, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey20', 'Base', 's', 'hotkey10', 's', 'hotkey20', 'Base', 's', 'hotkey30', 'hotkey40', 'hotkey00', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 'hotkey22', 's', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22'], []) - Score: 49812
# Player (402, 5) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 'hotkey10', 's', 'hotkey20', 'Base', 's', 'hotkey22', 'Base', 's', 'hotkey22', 'Base', 's', 's', 'hotkey20', 'Base', 's', 's', 'Base', 's', 'hotkey30', 'hotkey40', 'hotkey00', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12', 'hotkey22', 'Base', 's', 'hotkey22', 'hotkey32', 's', 'hotkey32', 'hotkey22', 'hotkey12'], []) - Score: 49812
# Player (402, 6) ranked combinations:
# Rank 1: (['s', 's', 's', 'Base', 's', 'hotkey10', 's', 'hotkey20', 'Base', 's', 'hotkey22', 'Base', 's', 'hotkey22', 'hotkey12', 's', 'Base', 's', 'hotkey30', 'hotkey40', 'hotkey00', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 'hotkey22', 's', 'hotkey12', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 's', 'hotkey32', 'hotkey22', 'Base', 's', 'hotkey22'], []) - Score: 49812
# Player (402, 7) ranked combinations:
# Rank 1: (['s', 's', 's', 'Base', 's', 'hotkey10', 's', 'hotkey20', 'Base', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 's', 'hotkey20', 'Base', 's', 'hotkey30', 'hotkey40', 'hotkey00', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey32', 'hotkey22', 'hotkey12', 's', 'hotkey12', 'hotkey22'], []) - Score: 49812
# Player (404, 0) ranked combinations:
# Rank 1: (['s', 'Base', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70'], []) - Score: 32516
# Player (404, 1) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 's', 'hotkey12'], []) - Score: 38192
# Player (404, 2) ranked combinations:
# Rank 1: (['Base', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 's', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12', 's'], []) - Score: 38192
# Player (404, 3) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 's', 'hotkey12'], []) - Score: 38192
# Player (404, 4) ranked combinations:
# Rank 1: (['Base', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70'], []) - Score: 32516
# Player (404, 5) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70'], []) - Score: 32516
# Player (404, 6) ranked combinations:
# Rank 1: (['Base', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70'], []) - Score: 32516
# Player (404, 7) ranked combinations:
# Rank 1: (['Base', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70'], []) - Score: 32516
# Player (404, 8) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 's', 'hotkey12', 's', 'hotkey12', 's'], []) - Score: 38192
# Player (404, 9) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 's'], []) - Score: 32516
# Player (404, 10) ranked combinations:
# Rank 1: (['s', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70'], []) - Score: 32516
# Player (404, 11) ranked combinations:
# Rank 1: (['Base', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70'], []) - Score: 32516
# Player (404, 12) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 's'], []) - Score: 32516
# Player (404, 13) ranked combinations:
# Rank 1: (['Base', 's', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 's', 'hotkey12'], []) - Score: 38192
# Player (404, 14) ranked combinations:
# Rank 1: (['Base', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 'hotkey80', 's', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12'], []) - Score: 38680
# Player (404, 15) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 's'], []) - Score: 32516
# Player (404, 16) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70'], []) - Score: 32516
# Player (404, 17) ranked combinations:
# Rank 1: (['Base', 's', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 's', 'hotkey12'], []) - Score: 38192
# Player (404, 18) ranked combinations:
# Rank 1: (['Base', 's', 's', 'Base', 's', 'hotkey10', 'hotkey30', 'hotkey00', 'hotkey70', 'hotkey80', 's', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12'], []) - Score: 38680
# Player (405, 0) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 'hotkey70', 'hotkey00', 'hotkey90', 'hotkey80', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's'], []) - Score: 41648
# Player (405, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey10', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 'hotkey70', 'hotkey00', 'hotkey90', 'hotkey80', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's'], []) - Score: 41648
# Player (405, 2) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 'hotkey70', 'hotkey00', 'hotkey90', 'hotkey80', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'SingleMineral', 's', 'hotkey22', 's', 'hotkey22'], []) - Score: 42188
# Player (405, 3) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 'hotkey70', 'hotkey00', 'hotkey90', 'hotkey80', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22'], []) - Score: 41648
# Player (406, 0) ranked combinations:
# Rank 1: (['s', 's', 'hotkey60', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62'], []) - Score: 27628
# Player (406, 1) ranked combinations:
# Rank 1: (['s', 'hotkey60', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62'], []) - Score: 27628
# Player (406, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey60', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62'], []) - Score: 27628
# Player (406, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey60', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62'], []) - Score: 27628
# Player (407, 0) ranked combinations:
# Rank 1: (['s', 'hotkey30', 's', 'hotkey32', 's', 's', 's', 's', 's', 's', 's', 'hotkey32', 'SingleMineral', 's', 's', 's', 's', 's', 's', 's', 'hotkey32', 'SingleMineral', 's'], []) - Score: 31750
# Player (407, 1) ranked combinations:
# Rank 1: (['s', 'hotkey30', 's', 's', 'hotkey32', 's', 's', 's', 's', 's', 's', 's', 's', 'hotkey32', 's', 's', 's', 's', 's', 's', 'hotkey32', 's', 's', 'hotkey32'], []) - Score: 31210
# Player (407, 2) ranked combinations:
# Rank 1: (['s', 'Base', 's', 'hotkey30', 's', 's', 's', 's', 's', 'hotkey32', 's', 's', 's', 's', 's', 'hotkey32', 'SingleMineral', 's', 's', 's', 'hotkey32', 's', 's', 's', 's', 'hotkey32'], []) - Score: 33670
# Player (407, 3) ranked combinations:
# Rank 1: (['Base', 's', 'hotkey30', 'SingleMineral', 's', 's', 'Base', 's', 's', 'Base', 's', 's', 'SingleMineral', 's', 'hotkey32', 's', 'hotkey32', 's', 'Base', 's', 's', 's', 's', 'hotkey32'], []) - Score: 33670
# Player (408, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey30', 'hotkey60', 'hotkey00', 's', 'hotkey62'], []) - Score: 30038
# Player (408, 1) ranked combinations:
# Rank 1: (['s', 's', 'hotkey30', 'hotkey60', 'hotkey00', 's', 'hotkey02', 's', 's', 'hotkey32'], []) - Score: 33248
# Player (408, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey30', 'hotkey60', 'hotkey00', 's', 'hotkey02', 's', 'hotkey32'], []) - Score: 33248
# Player (408, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey30', 'hotkey60', 'hotkey00', 's', 'hotkey62', 's', 'hotkey32'], []) - Score: 33865
# Player (408, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey30', 'hotkey60', 'hotkey00', 's', 'hotkey02', 's', 'hotkey32'], []) - Score: 33248
# Player (408, 5) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey40', 'hotkey60', 'hotkey00', 'hotkey30', 's', 'hotkey02', 's'], []) - Score: 30757
# Player (410, 0) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60'], []) - Score: 44824
# Player (410, 1) ranked combinations:
# Rank 1: (['s', 'hotkey10', 'hotkey20', 's', 's', 's', 'hotkey12', 's', 's', 'hotkey12', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22'], []) - Score: 40319
# Player (410, 2) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's'], []) - Score: 40319
# Player (410, 3) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60'], []) - Score: 44824
# Player (410, 4) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60'], []) - Score: 44824
# Player (410, 5) ranked combinations:
# Rank 1: (['s', 'hotkey10', 'hotkey20', 's', 's', 's', 'hotkey12', 's', 's', 'hotkey12', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22'], []) - Score: 40319
# Player (410, 6) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's'], []) - Score: 40319
# Player (410, 7) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60'], []) - Score: 44824
# Player (410, 8) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey10', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60'], []) - Score: 44824
# Player (410, 9) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 'hotkey22'], []) - Score: 40319
# Player (410, 10) ranked combinations:
# Player (410, 11) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey10', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12'], []) - Score: 40319
# Player (410, 12) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 's', 'hotkey10', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60'], []) - Score: 44824
# Player (410, 13) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22'], []) - Score: 40319
# Player (410, 14) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 's', 's', 's', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'SingleMineral', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22'], []) - Score: 40859
# Player (413, 0) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 2) ranked combinations:
# Rank 1: (['hotkey10', 'hotkey30', 's', 'hotkey32', 's', 's', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 3) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 's', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 5) ranked combinations:
# Rank 1: (['hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey12', 's', 'hotkey12'], []) - Score: 38730
# Player (413, 6) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 7) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 8) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 9) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 10) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 11) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 12) ranked combinations:
# Rank 1: (['hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey12', 's', 'hotkey12'], []) - Score: 38730
# Player (413, 13) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 's', 'hotkey32'], []) - Score: 33054
# Player (413, 14) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'hotkey30', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32'], []) - Score: 33054
# Player (414, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'SingleMineral', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42'], []) - Score: 41734
# Player (414, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42'], []) - Score: 41194
# Player (414, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 41194
# Player (414, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42'], []) - Score: 41194
# Player (414, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's'], []) - Score: 41194
# Player (414, 5) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'SingleMineral', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey10', 'hotkey42'], []) - Score: 41734
# Player (414, 6) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'Base', 's', 'hotkey40', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42'], []) - Score: 41194
# Player (414, 7) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42'], []) - Score: 41194
# Player (414, 8) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'SingleMineral', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 's'], []) - Score: 41734
# Player (415, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 's', 's', 's', 's', 's'], []) - Score: 34160
# Player (415, 1) ranked combinations:
# Rank 1: (['Base', 's', 's', 's', 's', 'Base', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's'], []) - Score: 43971
# Player (415, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 's', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's'], []) - Score: 42051
# Player (415, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 's'], []) - Score: 42051
# Player (415, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 's'], []) - Score: 42051
# Player (415, 5) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's'], []) - Score: 42051
# Player (415, 6) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 's', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 's', 's'], []) - Score: 42051
# Player (415, 7) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's'], []) - Score: 42051
# Player (415, 8) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'Base', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's'], []) - Score: 43971
# Player (415, 9) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 's', 's'], []) - Score: 42051
# Player (415, 10) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 's'], []) - Score: 42051
# Player (415, 11) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's'], []) - Score: 42051
# Player (415, 12) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'Base', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 's', 'hotkey52', 's'], []) - Score: 43971
# Player (415, 13) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 's', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 's', 's'], []) - Score: 42051
# Player (415, 14) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52'], []) - Score: 42051
# Player (415, 15) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 's', 's', 's', 's'], []) - Score: 34160
# Player (415, 16) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 'hotkey52', 's', 'hotkey52', 's'], []) - Score: 42051
# Player (415, 17) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 's'], []) - Score: 42051
# Player (415, 18) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 'hotkey60', 's', 'hotkey10', 'hotkey20', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's', 's', 'hotkey52', 'hotkey22', 'hotkey52', 'hotkey22', 'hotkey52', 's'], []) - Score: 42051
# Player (219517, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey50', 's', 'hotkey30', 'hotkey52', 'hotkey32', 'hotkey52', 's', 'hotkey52', 's', 'hotkey52', 's', 'hotkey52', 's', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 's', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 's', 'hotkey52'], []) - Score: 35099
# Player (219517, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey30', 's', 'hotkey50', 'hotkey32', 's', 'hotkey32', 's', 's', 'hotkey52', 's', 'hotkey52', 's', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 's', 'hotkey52'], []) - Score: 35099
# Player (219517, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey30', 's', 'hotkey50', 'hotkey32', 'hotkey52', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 's', 'hotkey32', 's', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52'], []) - Score: 35099
# Player (219517, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey30', 's', 'hotkey50', 'hotkey32', 's', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 's', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52'], []) - Score: 35099
# Player (219517, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey50', 's', 'hotkey30', 'hotkey52', 'hotkey32', 's', 'hotkey52', 's', 'hotkey52', 's', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52'], []) - Score: 35099
# Player (219517, 5) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey30', 's', 'hotkey50', 'hotkey32', 'hotkey52', 's', 'hotkey52', 'hotkey32', 'hotkey52', 's', 'hotkey52', 'hotkey32', 's', 'hotkey32', 's', 'hotkey32', 's', 'hotkey52', 'hotkey32'], []) - Score: 35099
# Player (219517, 6) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey30', 's', 'hotkey50', 's', 'hotkey32', 's', 'hotkey32', 's', 's', 'hotkey52', 's', 'hotkey52', 's', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52'], []) - Score: 35099
# Player (239335, 0) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey12'], []) - Score: 33374
# Player (239335, 1) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey12'], []) - Score: 33374
# Player (239335, 2) ranked combinations:
# Rank 1: (['s', 'hotkey10'], []) - Score: 27698
# Player (239335, 3) ranked combinations:
# Rank 1: (['s', 'hotkey10'], []) - Score: 27698
# Player (239335, 4) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'Base', 's', 's', 's', 's', 'hotkey20', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12'], []) - Score: 42239
# Player (239335, 5) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 's', 's', 's', 's', 's', 's', 'hotkey20', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12'], []) - Score: 40319
# Player (239335, 6) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 'hotkey12', 'hotkey22', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12', 's'], []) - Score: 40319
# Player (239335, 7) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 's', 'hotkey10', 'Base', 's', 'hotkey10', 's', 's', 's', 's', 's', 's', 's', 's', 'hotkey20', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12'], []) - Score: 42239
# Player (239335, 8) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'Base', 's', 's', 'hotkey20', 'hotkey12', 'hotkey22', 'hotkey12'], []) - Score: 42239
# Player (239335, 9) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20'], []) - Score: 29655
# Player (239335, 10) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 'hotkey12'], []) - Score: 35331
# Player (239335, 11) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 's', 's', 'hotkey20', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 's'], []) - Score: 40319
# Player (250458, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40'], []) - Score: 31067
# Player (250458, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40'], []) - Score: 31067
# Player (250458, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40'], []) - Score: 31067
# Player (250458, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40'], []) - Score: 31067
# Player (250458, 5) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40'], []) - Score: 31067
# Player (250458, 6) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40'], []) - Score: 31067
# Player (250458, 7) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 8) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 9) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 10) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40'], []) - Score: 31067
# Player (250458, 11) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 12) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 13) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20'], []) - Score: 27811
# Player (250458, 14) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 15) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40'], []) - Score: 31067
# Player (250458, 16) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 17) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 18) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 'Base', 's', 'hotkey40'], []) - Score: 31067
# Player (250458, 19) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey20', 'hotkey40'], []) - Score: 29147
# Player (250458, 20) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 21) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 22) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 23) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 's', 'hotkey40', 'hotkey22'], []) - Score: 34135
# Player (250458, 24) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 's', 'hotkey40', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 25) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 26) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's'], []) - Score: 38699
# Player (250458, 27) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (250458, 28) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40'], []) - Score: 29147
# Player (251061, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 'hotkey42'], []) - Score: 33598
# Player (251061, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 's', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 35518
# Player (251061, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 'hotkey42', 's', 's', 'hotkey42', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 's', 'hotkey42'], []) - Score: 33598
# Player (251061, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's'], []) - Score: 33598
# Player (251061, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 33598
# Player (251061, 5) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey40', 's', 'hotkey12', 's', 'hotkey42', 'hotkey12', 'hotkey42', 's', 's', 's', 's', 'hotkey42', 'hotkey12', 'hotkey42', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey12', 's', 'hotkey12', 'hotkey42', 's', 's'], []) - Score: 39274
# Player (251061, 6) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 'hotkey12', 'hotkey42', 's', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's'], []) - Score: 39274
# Player (251061, 7) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 'hotkey42', 'hotkey12', 'hotkey42', 's', 's', 'hotkey12', 'hotkey42', 'hotkey12', 's', 'hotkey42'], []) - Score: 39274
# Player (251061, 8) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 'hotkey12', 'hotkey42', 's', 's', 'hotkey42', 's', 's', 'hotkey12', 'hotkey42', 's', 's', 's', 's', 'hotkey42', 's', 's', 'hotkey12', 's', 'hotkey42', 's'], []) - Score: 39274
# Player (251061, 9) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 'hotkey12', 'hotkey42', 's', 's', 'hotkey12', 's', 'hotkey12', 'hotkey42', 's', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey12', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 's'], []) - Score: 39274
# Player (251061, 10) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 'hotkey12', 'hotkey42', 's', 's', 'hotkey12', 's', 'hotkey42', 's', 'hotkey42', 'hotkey12', 'hotkey42'], []) - Score: 39274
# Player (251061, 11) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 's', 'hotkey40', 'hotkey12', 'hotkey42', 's', 's', 'hotkey42', 's', 'Base', 's', 'hotkey40'], []) - Score: 41194
# Player (251061, 12) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 's', 'hotkey42', 's', 's', 's'], []) - Score: 33598
# Player (251061, 13) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 'hotkey42', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 33598
# Player (251061, 14) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 'hotkey42', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42'], []) - Score: 39274
# Player (251061, 15) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 's', 'hotkey42', 'SingleMineral', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's'], []) - Score: 34138
# Player (251061, 16) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 33598
# Player (251061, 17) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 33598
# Player (251061, 18) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 'Base', 's', 'hotkey40', 's', 'hotkey42', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 35518
# Player (251061, 19) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey40', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 33598
# Player (251061, 20) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey40', 's', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 33598
# Player (251061, 21) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey40', 's', 'hotkey42', 's', 's', 'hotkey42', 's', 's', 'hotkey42', 'hotkey12'], []) - Score: 39274
# Player (251061, 22) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey40', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 33598
# Player (284466, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey61', 's', 'hotkey62', 's'], []) - Score: 27017
# Player (284466, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey61', 's', 'hotkey62'], []) - Score: 27017
# Player (284466, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey61', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62'], []) - Score: 27017
# Player (284466, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey61', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62'], []) - Score: 27017
# Player (284466, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey60'], []) - Score: 26508
# Player (284466, 5) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey61', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62', 's', 'hotkey62'], []) - Score: 27017
# Player (284466, 6) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey61', 's', 's', 's', 'hotkey60', 's', 'hotkey62', 's', 'hotkey62'], []) - Score: 27671
# Player (288081, 0) ranked combinations:
# Rank 1: (['s', 'hotkey10', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 's', 'hotkey32', 's', 'hotkey22', 's', 'hotkey22'], []) - Score: 42321
# Player (288081, 1) ranked combinations:
# Rank 1: (['s', 'SingleMineral', 's', 'Base', 's', 'hotkey10', 'hotkey20', 'hotkey30', 'hotkey40', 'hotkey50', 's', 'hotkey22', 's', 'hotkey32', 's', 'hotkey32', 's', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey32', 's'], []) - Score: 44781
# Player (288081, 2) ranked combinations:
# ...
# Player (4863808, 10) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey90', 'hotkey80', 'hotkey70', 'hotkey60', 'hotkey50', 'hotkey40', 'hotkey30'], []) - Score: 46443
# Player (5068246, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40', 'hotkey22', 's', 's', 's', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 's', 'hotkey42', 'hotkey22', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 'hotkey22', 's'], []) - Score: 38699
# Player (5068246, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40', 'hotkey22', 's', 'hotkey22', 's', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 's', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42'], []) - Score: 38699
# Player (5068246, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 's', 's', 's'], []) - Score: 38699
# Player (5068246, 3) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 'Base', 's', 'hotkey40', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22', 's', 'hotkey22', 's', 's', 's', 's', 's', 'hotkey42', 'hotkey22', 'hotkey42', 'hotkey22'], []) - Score: 40619
# Player (5068246, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey20', 's', 'hotkey40', 'hotkey22', 'hotkey42', 'hotkey22', 'hotkey42', 's', 's', 's', 's', 's', 's', 's'], []) - Score: 38699
# Player (5087767, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 'Base', 's', 'hotkey80', 's', 'Base', 's', 's', 'hotkey60', 'hotkey82', 's', 's', 'hotkey62', 'hotkey82', 'hotkey62'], []) - Score: 30130
# Player (5087767, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 'Base', 's', 'hotkey80', 's', 'hotkey60', 'hotkey82', 'hotkey62', 'hotkey82', 'hotkey62', 'hotkey82', 'hotkey62', 'hotkey82'], []) - Score: 30130
# Player (5087767, 2) ranked combinations:
# Rank 1: (['Base', 's', 's', 's', 'Base', 's', 'hotkey80', 's', 'Base', 's', 's', 'hotkey60', 'hotkey82', 's', 'hotkey70', 'hotkey62', 'hotkey72', 'hotkey62', 'hotkey72', 'hotkey82', 'hotkey72', 'hotkey82', 's', 's'], []) - Score: 30685
# Player (5087767, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 'Base', 's', 'hotkey80', 's', 'Base', 's', 's', 'Base', 's', 'hotkey82', 's', 'hotkey60', 'hotkey82', 's', 'hotkey70', 'hotkey62', 'hotkey72', 'hotkey62', 'hotkey72', 'hotkey82', 'hotkey72', 's', 'hotkey60', 'hotkey82', 'hotkey72', 'hotkey82', 'hotkey62'], []) - Score: 30685
# Player (5087767, 4) ranked combinations:
# Rank 1: (['Base', 's', 's', 's', 'Base', 's', 'hotkey80', 's', 'Base', 's', 's', 'hotkey60', 'hotkey82', 's', 'hotkey70', 'hotkey62', 'hotkey72', 'hotkey62', 'hotkey82', 's', 'hotkey62', 'hotkey82', 's', 'hotkey62', 'hotkey82', 'hotkey72', 'hotkey82', 'hotkey72', 'hotkey62'], []) - Score: 30685
# Player (5087767, 5) ranked combinations:
# Rank 1: (['s', 'Base', 's', 's', 'Base', 's', 's', 'Base', 's', 'hotkey80', 's', 'hotkey82', 's', 'hotkey60', 'hotkey82', 's', 'hotkey70', 'hotkey62', 'hotkey72', 'hotkey62', 'hotkey72', 'hotkey62', 'hotkey72', 'hotkey62', 'hotkey72'], []) - Score: 30685
# Player (5142993, 0) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22'], []) - Score: 40319
# Player (5142993, 1) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey10', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey12', 'hotkey22'], []) - Score: 40319
# Player (5142993, 2) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey10', 's', 'hotkey10', 'hotkey20', 's', 's', 's', 'hotkey12', 's', 's', 'hotkey12', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12'], []) - Score: 40319
# Player (5142993, 3) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey10', 'hotkey22', 'hotkey12', 'hotkey22', 's'], []) - Score: 40319
# Player (5142993, 4) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey10', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 's', 's', 'hotkey12', 'hotkey22'], []) - Score: 40319
# Player (5142993, 5) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 'hotkey10', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22'], []) - Score: 40319
# Player (5142993, 6) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22'], []) - Score: 40319
# Player (5142993, 7) ranked combinations:
# Rank 1: (['s', 'hotkey10', 's', 'hotkey20', 'SingleMineral', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey10', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's'], []) - Score: 40859
# Player (5142993, 8) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey12', 'hotkey22', 's'], []) - Score: 40319
# Player (5142993, 9) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12'], []) - Score: 40319
# Player (5142993, 10) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey12', 'hotkey22', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 's', 'hotkey22', 'hotkey12', 'hotkey22', 'hotkey12', 'hotkey22', 's'], []) - Score: 40319
# Player (5376901, 0) ranked combinations:
# Rank 1: (['s', 's', 'Base', 's', 'hotkey10', 's', 'hotkey20', 'hotkey12', 's', 's', 's', 'hotkey22', 'hotkey12'], []) - Score: 42239
# Player (5376901, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 'hotkey12', 's', 'hotkey22', 'hotkey12', 's', 'SingleMineral', 's', 's', 'hotkey22', 'hotkey12', 's', 's', 's', 'hotkey22', 'hotkey12'], []) - Score: 40859
# Player (5376901, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 'hotkey12', 's', 'hotkey22', 'hotkey12'], []) - Score: 40319
# Player (5376901, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey20', 'hotkey10', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 's', 's', 's', 's', 'hotkey22', 'hotkey12', 's'], []) - Score: 40319
# Player (5376901, 4) ranked combinations:
# Rank 1: (['s', 's', 'hotkey20', 's', 'hotkey10', 's', 's', 's', 'hotkey12', 's', 'hotkey22', 'hotkey12', 's', 's'], []) - Score: 40319
# Player (5376901, 5) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 's', 's', 'hotkey12', 's', 'hotkey22', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12', 'hotkey22', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12', 'hotkey22', 'hotkey12', 's'], []) - Score: 40319
# Player (5376901, 6) ranked combinations:
# Player (5376901, 7) ranked combinations:
# Rank 1: (['s', 's', 's', 'Base', 's', 'hotkey10', 's', 'hotkey20', 'Base', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 's', 's', 'hotkey12', 's', 'hotkey22', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12', 'hotkey22', 'hotkey12'], []) - Score: 42239
# Player (5376901, 8) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 'hotkey22', 'hotkey12', 's', 's', 's', 'hotkey12', 'hotkey22', 'hotkey12', 's', 'hotkey12', 's', 'hotkey22', 'hotkey12', 's', 'hotkey12', 'hotkey22', 'hotkey12'], []) - Score: 40319
# Player (5376901, 9) ranked combinations:
# Rank 1: (['s', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 'hotkey12', 'hotkey22'], []) - Score: 40319
# Player (5376901, 10) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 's', 'hotkey22', 'hotkey12', 's', 'hotkey12', 's', 'hotkey12', 'hotkey22', 'hotkey12', 's', 's', 's', 'hotkey12'], []) - Score: 40319
# Player (5376901, 11) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 'hotkey22', 'hotkey12', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 's'], []) - Score: 40319
# Player (5376901, 12) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey10', 's', 'hotkey20', 's', 's', 's', 's', 's', 'hotkey22', 'hotkey12', 's', 'hotkey12', 's'], []) - Score: 40319
# Player (5393959, 0) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 's', 's', 'Base', 's', 'hotkey50', 's', 'hotkey30', 'hotkey52'], []) - Score: 33192
# Player (5393959, 1) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 's', 's', 'Base', 's', 'hotkey50'], []) - Score: 28760
# Player (5393959, 2) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's'], []) - Score: 25854
# Player (5393959, 3) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey30', 's', 's', 's', 's', 's', 'hotkey50', 'hotkey90', 'hotkey80', 'hotkey70', 'hotkey60', 's', 'hotkey00', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32'], []) - Score: 38253
# Player (5393959, 4) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 's', 'hotkey50', 's', 'hotkey30', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey90', 'hotkey80'], []) - Score: 36230
# Player (5393959, 5) ranked combinations:
# Rank 1: (['s', 's', 'hotkey30', 'Base', 's', 's', 'Base', 's', 'hotkey50', 'hotkey90', 'hotkey80', 'hotkey70', 'hotkey60', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 's'], []) - Score: 39292
# Player (5393959, 6) ranked combinations:
# Rank 1: (['s', 's', 's', 's'], []) - Score: 25854
# Player (5393959, 7) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 's', 'hotkey50', 's', 'hotkey30', 'hotkey52'], []) - Score: 31272
# Player (5393959, 8) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 's', 's', 's'], []) - Score: 25854
# Player (5393959, 9) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey30', 's', 's', 'hotkey50', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey90', 'hotkey80', 'hotkey70', 'hotkey60', 'hotkey32', 'hotkey00'], []) - Score: 38253
# Player (5393959, 10) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey30', 's', 's', 's', 'hotkey50', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52'], []) - Score: 35099
# Player (5393959, 11) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 'Base', 's', 's', 'Base', 's', 'hotkey50', 's', 'hotkey30', 'hotkey52', 'hotkey32'], []) - Score: 37019
# Player (5393959, 12) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey50', 'hotkey80', 'hotkey70', 'hotkey60', 's', 'hotkey30', 'hotkey00', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32', 'hotkey52', 's'], []) - Score: 37610
# Player (5393959, 13) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 's', 'hotkey50', 's', 'hotkey30', 'hotkey52', 'hotkey32', 'hotkey52', 'hotkey32'], []) - Score: 35099
# Player (5393959, 14) ranked combinations:
# Rank 1: (['s', 's', 's', 'hotkey30', 's', 'hotkey50', 'hotkey80', 'hotkey70', 'hotkey60', 'hotkey32', 'hotkey52', 'hotkey32'], []) - Score: 36729
# Player (5393959, 15) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 's'], []) - Score: 25854
# Player (5393959, 16) ranked combinations:
# Rank 1: (['s', 's', 's', 's', 's', 's'], []) - Score: 25854
# Player (5495016, 0) ranked combinations:
# Rank 1: (['Base', 's', 's', 'hotkey10', 'Base', 's', 'hotkey40', 's', 'hotkey42', 's', 'hotkey42', 'hotkey12', 'hotkey42', 's', 'hotkey42', 's', 'hotkey12', 'hotkey42', 'hotkey12'], []) - Score: 41194
# Player (5495016, 1) ranked combinations:
# Rank 1: (['s', 'hotkey40', 'hotkey70', 'hotkey90', 'hotkey00', 'hotkey80', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 34254
# Player (5495016, 2) ranked combinations:
# Rank 1: (['s', 'hotkey40', 'hotkey70', 'hotkey00', 'hotkey90', 'hotkey80', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 34254
# Player (5495016, 3) ranked combinations:
# Rank 1: (['s', 'hotkey40', 'hotkey70', 'hotkey80', 'hotkey90', 'hotkey00', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42', 's', 'hotkey42'], []) - Score: 34254
# Ranked combinations saved to ranked_combinations.txt

# %% [markdown]
# At this point we stopped as we realised that we should create a training model that find the best sequence of actions for each player based on the ranking and then combine this model with others, as RandomForest, in order to predict in the most accurate way the player based also on the total time of the race and on other features.

# %% [markdown]
# ## Choosing a model
#
# Choosing the right model is crucial, because it directly influences the accuracy of the predictions and therefor impacts the overall success and reliability of our system. We will evaluate the different models we tried by using the F1 accuracy and cross-validation.

# %%
# Target
labels = train_data_new['PlayerID']

# Keep only the columns we need as features
features = train_data_new.drop(['PlayerID'], axis=1)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(features, labels, test_size=0.2, random_state=42)

# %% [markdown]
# We started by using the TreeClassifier. This gave us a training accuracy of 76%.

# %%
# Choose Decision Tree as a model and train it
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Predictions on the val set
predictions = model.predict(X_val)

# Evaluation of model
accuracy = accuracy_score(y_val, predictions)
print(f'Accuracy: {accuracy}')

f1_DT = f1_score(y_val, predictions, average='micro')
print(f'F1 Score on Validation Set: {f1_DT}')

scores = cross_val_score(model, features, labels, cv=4)
print(f'Cross Validation Scores: {scores}')
# Out:
# Accuracy: 0.7610474631751227
# F1 Score on Validation Set: 0.7610474631751227
# Cross Validation Scores: [0.7051114  0.77588467 0.78505898 0.72608126]

# %% [markdown]
# With the RandomForest we were able to increase the training accuracy to 92%

# %%
# Choose Random Forest as a model and train it
model = RandomForestClassifier(random_state=42, n_estimators=200)
model.fit(X_train, y_train)

# Predictions on the val set
predictions = model.predict(X_val)

# Evaluation of model
accuracy = accuracy_score(y_val, predictions)
print(f'Accuracy: {accuracy}')

f1_DT = f1_score(y_val, predictions, average='micro')
print(f'F1 Score on Validation Set: {f1_DT}')

scores = cross_val_score(model, features, labels, cv=4)
print(f'Cross Validation Scores: {scores}')
# Out:
# Accuracy: 0.9263502454991817
# F1 Score on Validation Set: 0.9263502454991817
# Cross Validation Scores: [0.90432503 0.92529489 0.92529489 0.92267366]

# %% [markdown]
# For the following changes we were not able to increase our training accuracy. In return they improved our testing accuracy on kaggle and therefore also our model. Firstly we performed hyperparameter tuning using GridSearchCV on the RandomForest.

# %%
# Choose a model and train it
model = RandomForestClassifier(random_state=42, n_estimators=200)

# Hyperparameter tuning using GridSearchCV
param_grid = {'n_estimators': [100, 150, 200], 'max_depth': [None, 10, 20]}
grid_search = GridSearchCV(model, param_grid, cv=4, n_jobs=-1)
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_

# Use the best model for predictions
predictions = best_model.predict(X_val)

# Evaluation of model
accuracy = accuracy_score(y_val, predictions)
print(f'Accuracy: {accuracy}')

f1_DT = f1_score(y_val, predictions, average='micro')
print(f'F1 Score on Validation Set: {f1_DT}')

scores = cross_val_score(best_model, features, labels, cv=4)
print(f'Cross Validation Scores: {scores}')
# Out:
# Accuracy: 0.9263502454991817
# F1 Score on Validation Set: 0.9263502454991817
# Cross Validation Scores: [0.90432503 0.92529489 0.92529489 0.92267366]

# %% [markdown]
# Then we tested our model and plotted which features contributed the most to the predictions.
# [You can find the results here](Feature_Importance.ipynb). We did this with the help of RandomForest feature importace. It is a measure of the contribution of each feature to the overall predictive performance of the model.
# We then removed 30% of the least important features. The F1 score stayed the same for the training and testing, so to reduce dimensions we decided to stick to the smaller table.

# %%
# Remove 30% of least important features
columns_to_remove = ['hk1_t5_Frequency', 'race_Zerg', 'hk9_t60_Frequency', 'hk5_t5_Frequency', 'hk7_t60_Frequency', 'hk7_t550_Frequency', 'hk9_t340_Frequency', 'hk0_t20_Frequency', 'hk6_t20_Frequency', 'base_t20_Frequency', 'hk8_t200_Frequency', 'hk7_t270_Frequency', 'hk9_t20_Frequency', 'base_t5_Frequency', 'hk9_t200_Frequency', 'hk7_t340_Frequency', 'singleMineral_t550_Frequency', 'singleMineral_t200_Frequency', 'singleMineral_t340_Frequency', 'hk9_t270_Frequency', 'sFrequency', 'hk8_t100_Frequency', 'hk0_t5_Frequency', 'race_Terran', 'singleMineralFrequency', 'hk7_t20_Frequency', 'singleMineral_t270_Frequency', 'singleMineral_t100_Frequency', 'hk8_t60_Frequency', 'hk8_t20_Frequency', 'singleMineral_t60_Frequency', 'hk6_t5_Frequency', 'hk7_t5_Frequency', 'hk8_t5_Frequency', 'singleMineral_t20_Frequency', 'singleMineral_t5_Frequency']
# Remove columns from DataFrame
train_data_new = train_data_new.drop(columns=columns_to_remove)

# Saving them in a csv file
train_data_new.to_csv('actiontype_count.csv', index=False)

train_data_new.head()

# Target
labels = train_data_new['PlayerID']

# Keep only the columns we need as features
features = train_data_new.drop(['PlayerID'], axis=1)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(features, labels, test_size=0.2, random_state=42)

# Choose a model and train it
model = RandomForestClassifier(random_state=42, n_estimators=200)

# Hyperparameter tuning using GridSearchCV
param_grid = {'n_estimators': [100, 150, 200], 'max_depth': [None, 10, 20]}
grid_search = GridSearchCV(model, param_grid, cv=4, n_jobs=-1)
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_

# Save the best model to a file
joblib.dump(boosting_model, 'player_id_prediction_model.pkl')


# Use the best model for predictions
predictions = best_model.predict(X_val)

# Evaluation of model
accuracy = accuracy_score(y_val, predictions)
print(f'Accuracy: {accuracy}')

f1_DT = f1_score(y_val, predictions, average='micro')
print(f'F1 Score on Validation Set: {f1_DT}')

scores = cross_val_score(best_model, features, labels, cv=4)
print(f'Cross Validation Scores: {scores}')

# %% [markdown]
# To increase the testing accuracy even further we added the AdaBoost method. It focuses on instances that are difficult to classify and thus complemented the RandomForest method.

# %%
 # Choose the boosting algorithm (AdaBoost)
 boosting_model = AdaBoostClassifier(best_model)

 boosting_model.fit(X_train, y_train)

 # Save the best model to a file
 joblib.dump(boosting_model, 'player_id_prediction_model.pkl')

 # Use the best model for predictions
 predictions = boosting_model.predict(X_val)

 # Evaluation of model
 accuracy = accuracy_score(y_val, predictions)
 print(f'Accuracy: {accuracy}')

 f1_DT = f1_score(y_val, predictions, average='micro')
 print(f'F1 Score on Validation Set: {f1_DT}')

 scores = cross_val_score(boosting_model, features, labels, cv=4)
 print(f'Cross Validation Scores: {scores}')
# Out:
# Accuracy: 0.9312602291325696
# F1 Score on Validation Set: 0.9312602291325697
# Cross Validation Scores: [0.9017038  0.93709043 0.93053735 0.92791612]

# %% [markdown]
# Furthermore we tried to use different ensemble methods: Stacking and Voting. With neither of them we achieved a higher score of accuracy so we decided to leave them out.

# %% [markdown]
# ## Testing
#
# When given the test data we were looking at almost the same pattern as the training data: Each row was a gameplay with a race and the moves made. Just the identifaction of the player was missing. That one was for us to predict and to do so we used our pretrained model.

# %%
# Load new data file 
test_data = pd.read_csv('test_data.csv', delimiter=';')
test_data.columns = ['Race'] + [f'Move_{i}' for i in range(1, 3446)]
test_data.head()
# Out:
#       Race Move_1    Move_2    Move_3    Move_4    Move_5    Move_6    Move_7  \
# 0     Zerg      s         s         s  hotkey10         s  hotkey60         s
# 1   Terran      s  hotkey30  hotkey00        t5         s  hotkey32         s
# 2  Protoss   Base         s         s      Base         s  hotkey20  hotkey30
# 3     Zerg      s         s         s         s  hotkey20         s  hotkey40
# 4  Protoss   Base         s         s      Base         s  hotkey50  hotkey30
#
#      Move_8    Move_9  ... Move_3436 Move_3437 Move_3438 Move_3439 Move_3440  \
# 0  hotkey00         s  ...         s  hotkey11  hotkey12  hotkey02  hotkey62
# 1  hotkey32         s  ...       NaN       NaN       NaN       NaN       NaN
# 2  hotkey60  hotkey40  ...     t1110  hotkey22  hotkey62  hotkey22  hotkey12
# 3        t5       t10  ...       NaN       NaN       NaN       NaN       NaN
# 4        t5  hotkey40  ...       NaN       NaN       NaN       NaN       NaN
#
#   Move_3441 Move_3442 Move_3443 Move_3444 Move_3445
# 0  hotkey12         s  hotkey02  hotkey62  hotkey12
# 1       NaN       NaN       NaN       NaN       NaN
# 2  hotkey22         s  hotkey72     t1115  hotkey22
# 3       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 3446 columns]

# %% [markdown]
# ### Testing Pre-processing
#
# But before, we had to change the data in the same way we did with the training data. We did this, so they would be able to compare.

# %%
# Same preprocessing as in train_def so that we have save structured data
def count_moves(row, counts, index):
    total_moves = 0
    for i in range(1, 3446):
        move = row["Move_"+ str(i)]

        # count the number of s's
        if move == 's':
            counts[10][index] += 1
        # count the number of Base's
        elif move == 'Base':
            counts[11][index] += 1
        # count the number of SingleMineral's
        elif move == 'SingleMineral':
            counts[12][index] += 1
        # count the hotkeys
        elif isinstance(move, str):
            for j in range(10):
                if move.startswith(f"hotkey{j}"):
                    counts[j][index] += 1
        total_moves += 1  
    # Save the total moves count
    counts[13][index] = total_moves


def count_move_per_time(row, counts, row_index, time_interval, ti_index):
    base_index = ti_index*14
    total_moves = 0
    for i in range(1, 3446):
        move = row["Move_" + str(i)]

        # Count actions for the given time interval
        if move == 's':
            counts[base_index + 10][row_index] += 1
        elif move == 'Base':
            counts[base_index + 11][row_index] += 1
        elif move == 'SingleMineral':
            counts[base_index + 12][row_index] += 1
        elif isinstance(move, str):
            for j in range(10):
                if move.startswith(f"hotkey{j}"):
                    counts[base_index + j][row_index] += 1

        total_moves += 1

        # Continue counting actions after the specified time interval
        if move == f't{time_interval}':
            break

    counts[base_index + 13][row_index] = total_moves


def mapRaces(races, row_index):
    race = test_data['Race'][row_index]

    if race == "Protoss":
        races[0][row_index] = 1
    elif race == "Terran":
        races[1][row_index] = 1
    elif race == "Zerg":
        races[2][row_index] = 1
        

# Create new table that only contains the first column (Race) of test_data
# Keep only the first column but all rows
test_data_new = test_data.iloc[:, :1]

# Specify the target time intervals
# time_intervals = [20, 60, 100, 200]
time_intervals = [5, 20, 60, 100, 200, 270, 340, 550]

calc_column = len(time_intervals)* 14 + 14
# New lists of counts
counts = [[0] * 340 for _ in range(calc_column)]
# New lists of races
races = [[0] * 340 for _ in range(3)]


# Go through the rows using the functions to count the actions, map the races
for row_index, row in test_data.iterrows():
    count_moves(row, counts, row_index)
    mapRaces(races, row_index)

    for ti_index, time_interval in enumerate(time_intervals):
        count_move_per_time(row, counts, row_index, time_interval, ti_index+1)

# Adding all the new columns to the test_data_new
# Adding new columns for the count of moves
for i in range(calc_column):
    locals()[f'count_{i}'] = counts[i]

for i in range(10):
    test_data_new[f'hk{i}Frequency'] = [count / counts[13][index] if counts[13][index] != 0 else 0 for index, count in enumerate(counts[i])]

test_data_new['sFrequency'] = [count / counts[13][index] if counts[13][index] != 0 else 0 for index, count in enumerate(counts[10])]
test_data_new['baseFrequency'] = [count / counts[13][index] if counts[13][index] != 0 else 0 for index, count in enumerate(counts[11])]
test_data_new['singleMineralFrequency'] = [count / counts[13][index] if counts[13][index] != 0 else 0 for index, count in enumerate(counts[12])]

# Adding new columns for the count of moves per interval
for ti_index, time_interval in enumerate(time_intervals):
    base_index = (ti_index + 1) * 14
    for j in range(10):
        column_name = f'hk{j}_t{time_interval}_Frequency'
        test_data_new[column_name] = [count / counts[base_index + 13][index] if counts[base_index + 13][index] != 0 else 0 for index, count in enumerate(counts[base_index + j])]

    test_data_new[f's_t{time_interval}_Frequency'] = [count / counts[base_index + 13][index] if counts[base_index + 13][index] != 0 else 0 for index, count in enumerate(counts[base_index + 10])]
    test_data_new[f'base_t{time_interval}_Frequency'] = [count / counts[base_index + 13][index] if counts[base_index + 13][index] != 0 else 0 for index, count in enumerate(counts[base_index + 11])]
    test_data_new[f'singleMineral_t{time_interval}_Frequency'] = [count / counts[base_index + 13][index] if counts[base_index + 13][index] != 0 else 0 for index, count in enumerate(counts[base_index + 12])]



# Adding new columns for the races
test_data_new['race_Protoss'] = races[0]
test_data_new['race_Terran'] = races[1]
test_data_new['race_Zerg'] = races[2]

# Remove 30% of least important features
columns_to_remove = ['hk1_t5_Frequency', 'race_Zerg', 'hk9_t60_Frequency', 'hk5_t5_Frequency', 'hk7_t60_Frequency', 'hk7_t550_Frequency', 'hk9_t340_Frequency', 'hk0_t20_Frequency', 'hk6_t20_Frequency', 'base_t20_Frequency', 'hk8_t200_Frequency', 'hk7_t270_Frequency', 'hk9_t20_Frequency', 'base_t5_Frequency', 'hk9_t200_Frequency', 'hk7_t340_Frequency', 'singleMineral_t550_Frequency', 'singleMineral_t200_Frequency', 'singleMineral_t340_Frequency', 'hk9_t270_Frequency', 'sFrequency', 'hk8_t100_Frequency', 'hk0_t5_Frequency', 'race_Terran', 'singleMineralFrequency', 'hk7_t20_Frequency', 'singleMineral_t270_Frequency', 'singleMineral_t100_Frequency', 'hk8_t60_Frequency', 'hk8_t20_Frequency', 'singleMineral_t60_Frequency', 'hk6_t5_Frequency', 'hk7_t5_Frequency', 'hk8_t5_Frequency', 'singleMineral_t20_Frequency', 'singleMineral_t5_Frequency']
# Remove columns from DataFrame
test_data_new = test_data_new.drop(columns=columns_to_remove)

# Saving them in a csv file
test_data_new.to_csv('actiontype_count_test.csv', index=False)

test_data_new.head()
# Out:
#       Race  hk0Frequency  hk1Frequency  hk2Frequency  hk3Frequency  \
# 0     Zerg      0.249927      0.113208      0.022351      0.001451
# 1   Terran      0.010160      0.101597      0.052540      0.135849
# 2  Protoss      0.000290      0.128882      0.178520      0.084180
# 3     Zerg      0.000000      0.197968      0.042961      0.010450
# 4  Protoss      0.000871      0.024673      0.011030      0.007837
#
#    hk4Frequency  hk5Frequency  hk6Frequency  hk7Frequency  hk8Frequency  ...  \
# 0      0.000000      0.000000      0.285922      0.013643      0.000000  ...
# 1      0.117562      0.045864      0.000000      0.000000      0.000000  ...
# 2      0.063570      0.000000      0.305660      0.009289      0.014224  ...
# 3      0.154427      0.001451      0.001161      0.000000      0.000000  ...
# 4      0.008418      0.024383      0.000000      0.001161      0.001451  ...
#
#    hk6_t550_Frequency  hk7_t550_Frequency  hk8_t550_Frequency  \
# 0            0.322067            0.015451            0.000000
# 1            0.000000            0.000000            0.000000
# 2            0.356610            0.005330            0.014392
# 3            0.000000            0.000000            0.000000
# 4            0.000000            0.005319            0.008865
#
#    hk9_t550_Frequency  s_t550_Frequency  base_t550_Frequency  \
# 0            0.010623          0.201352             0.008209
# 1            0.012234          0.205409             0.000000
# 2            0.000000          0.139126             0.002132
# 3            0.000000          0.378223             0.010506
# 4            0.000000          0.345745             0.035461
#
#    singleMineral_t550_Frequency  race_Protoss  race_Terran  race_Zerg
# 0                      0.001449             0            0          1
# 1                      0.000000             0            1          0
# 2                      0.000000             1            0          0
# 3                      0.000955             0            0          1
# 4                      0.000000             1            0          0
#
# [5 rows x 121 columns]

# %% [markdown]
# ### Testing Predictions
#
# The pre-trained model was then loaded and used to make predictions about the players.

# %%
# Load the pre-trained model
model_filename = 'player_id_prediction_model.pkl'
clf = joblib.load(model_filename)

features = test_data_new.drop(['Race'], axis=1)

# Use the loaded model to make predictions
predictions = clf.predict(features)

# Add predictions to the test_data_new DataFrame
test_data_new['Predicted_PlayerID'] = predictions

test_data_new.head()

# %% [markdown]
# At the end we created a .csv file with the results that we could upload to Kaggle. This meant merging the predicted player IDs with the first row of the training data to obtain the corresponding player URLs.

# %%
# Load the training dataset
train_data = pd.read_csv('train_data.csv', delimiter=';')

# Extract 'PlayerID' and 'PlayerURL' columns
player = train_data[['PlayerID', 'PlayerURL']]

# take only one URL per each PlayerID
player_info = player.drop_duplicates(subset='PlayerID', keep='first')

# Extract 'Predicted_PlayerID' column
player_id_column = test_data_new[['Predicted_PlayerID']]

# Merge the predicted ID to get the url of the player
result = pd.merge(player_id_column, player_info, left_on='Predicted_PlayerID', right_on='PlayerID', how='left')

# take only the url for each player
result = result.drop(['Predicted_PlayerID', 'PlayerID'], axis=1)
# insert a new row in position 0 as asked for the submission and count the number of lines
result.insert(0,"RowId", range(1, len(result) + 1))

# Save 'PlayerURL' to CSV
result.to_csv('player_id_only.csv', index=False)

#player_info.head()
#player_id_column.head()
result.head()

# %% [markdown]
# Afterwards we added some statistics to asses the testing performance. We wanted to see which predictions were made

# %%
print("Count of Predicted PlayerIDs:")
print(test_data_new['Predicted_PlayerID'].value_counts())

# %% [markdown]
# And we wanted to see how many different players were predicted. We increased this score over time, because it meant our model was able differentiate better between players.

# %%
print("Count of Unique PlayerURLs:")
print(result['PlayerURL'].nunique())

# %% [markdown]
# ## Results
#
# The first time we tested our model we only reached 44% on Kaggle. Over time, we managed to increase this score more and more. Finally, we reached a level of 82% testing accuracy and 92% training accuracy.
#
# ### Improvements
# We could make some improvements to our code by doing:
# - Feature Engineering:
#     We should consider additional features or transformations that might better capture the characteristics of our data and experiment with different aggregations, scaling, or encoding techniques. Another thing to do could be to check for highly correlated features and trying top remove the correlated features to reduce multicollinearity.
# - Model Selection:
#     Apart from the model already used, we could experiment with different machine learning models, that combines the results of other models, in order to obtain better results. Some examples could be Gradient Boosting, Support Vector Machines, or Neural Networks, which may capture complex patterns in the data.
